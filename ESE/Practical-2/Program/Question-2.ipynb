# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('E:/KARAN-ICT/SEMETSER-6/ML/Practical Exam/Question 2.csv')
data
# Out:
#      INCOME  SPEND
# 0       233    150
# 1       250    187
# 2       204    172
# 3       236    178
# 4       354    163
# ..      ...    ...
# 298     241    123
# 299     264    132
# 300     193    141
# 301     131    115
# 302     236    174
#
# [303 rows x 2 columns]

# %%
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = (30, 8)
sns.countplot(data['INCOME'])
plt.title('Income distribution', fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (30, 8)
sns.countplot(data['SPEND'])
plt.title('Spending distribution', fontsize = 20)
plt.show()

# %%
X= data.iloc[:, [0,1]].values

# %%
from sklearn.cluster import KMeans
#Elbow method
wcss=[]
for i in range(1,10):
    kmeans = KMeans(n_clusters= i, init='k-means++', random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,10), wcss)
plt.title('The Elbow Method')
plt.xlabel('no of clusters')
plt.ylabel('wcss')
plt.show()

# %%
kmeansmodel = KMeans(n_clusters= 5, init='k-means++', random_state=0)
y_kmeans= kmeansmodel.fit_predict(X)


plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'blue', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'violet', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'black', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'red', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'green', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Income')
plt.ylabel('Spending')
plt.legend()
plt.show()

# %%
c1 = data[y_kmeans==0]
c2 = data[y_kmeans==1]
c3 = data[y_kmeans==2]
c4 = data[y_kmeans==3]
c5 = data[y_kmeans==4]

# %%
print("percent of people are blessed with living with luxury: ",(c5.shape[0]*100)/data.shape[0])
print("percent of people living luxury having low income  : ",(c1.shape[0]*100)/data.shape[0])
print("percentage of people intrested in savings for future purpose: ",(c4.shape[0]*100)/data.shape[0])
print("percent of people cannot afford to spend money on their luxury: ",(c3.shape[0]*100)/data.shape[0])
# Out:
# percent of people are blessed with living with luxury:  16.17161716171617
# percent of people living luxury having low income  :  15.511551155115512
# percentage of people intrested in savings for future purpose:  33.663366336633665
# percent of people cannot afford to spend money on their luxury:  17.16171617161716
