# %% [markdown]
# <a href="https://colab.research.google.com/github/karandoshi1810/Machine-Learning/blob/main/ANALYTICAL_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-surprise

# %%
from surprise import SVD
from surprise import NMF,KNNBasic
from surprise import Dataset
from surprise.model_selection import cross_validate
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
# Load the movielens-100k dataset (download it if needed).
data = Dataset.load_builtin('ml-100k')

# Use the famous SVD algorithm.
algo = SVD()

# Run 5-fold cross-validation and print results.
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9382  0.9302  0.9372  0.9386  0.9372  0.9363  0.0031
# MAE (testset)     0.7402  0.7366  0.7396  0.7388  0.7373  0.7385  0.0014
# Fit time          4.06    4.06    4.09    4.04    4.05    4.06    0.02
# Test time         0.33    0.15    0.18    0.15    0.23    0.21    0.07
# {'fit_time': (4.064582824707031,
#   4.064817428588867,
#   4.092864036560059,
#   4.043591499328613,
#   4.050857067108154),
#  'test_mae': array([0.74018816, 0.73659146, 0.73956665, 0.73884181, 0.7372555 ]),
#  'test_rmse': array([0.93822099, 0.93015811, 0.93722255, 0.93863993, 0.93724114]),
#  'test_time': (0.3331925868988037,
#   0.1494760513305664,
#   0.18075919151306152,
#   0.15137362480163574,
#   0.23187661170959473)}

# %%
import pandas as pd

df=pd.read_csv("jester-data-1_new.csv")
df=df.drop(['Number of Ratings'],axis=1)
df
# Out:
#        UserID    J1    J2    J3    J4    J5  ...   J95   J96   J97   J98     J  J100
# 0          U1 -7.82  8.79 -9.66 -8.16 -7.52  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1          U2  4.08 -0.29  6.36  4.37 -2.38  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2          U3   NaN   NaN   NaN   NaN  9.03  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3          U4   NaN  8.35   NaN   NaN  1.80  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4          U5  8.50  4.61 -4.17 -5.39  1.36  ...  5.73  1.55  3.11  6.55  1.80  1.60
# ...       ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 24978  U24979  0.44  7.43  9.08  2.33  3.20  ...  8.45  9.03  6.55  8.69  8.79  7.43
# 24979  U24980  9.13 -8.16  8.59  9.08  0.87  ...  9.22 -8.20 -7.23 -8.59  9.13  8.45
# 24980  U24981   NaN   NaN   NaN   NaN -7.77  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 24981  U24982   NaN   NaN   NaN   NaN -9.71  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df2=df
df2
# Out:
#        UserID    J1    J2    J3    J4    J5  ...   J95   J96   J97   J98     J  J100
# 0          U1 -7.82  8.79 -9.66 -8.16 -7.52  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1          U2  4.08 -0.29  6.36  4.37 -2.38  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2          U3   NaN   NaN   NaN   NaN  9.03  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3          U4   NaN  8.35   NaN   NaN  1.80  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4          U5  8.50  4.61 -4.17 -5.39  1.36  ...  5.73  1.55  3.11  6.55  1.80  1.60
# ...       ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 24978  U24979  0.44  7.43  9.08  2.33  3.20  ...  8.45  9.03  6.55  8.69  8.79  7.43
# 24979  U24980  9.13 -8.16  8.59  9.08  0.87  ...  9.22 -8.20 -7.23 -8.59  9.13  8.45
# 24980  U24981   NaN   NaN   NaN   NaN -7.77  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 24981  U24982   NaN   NaN   NaN   NaN -9.71  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
colname=df2.columns[1:101]

# %%
df3=(df.values)   #df2[:,1:102]

# %%
ratings=(df3[:,1:102].ravel())
ratings.size
# Out:
# 2498300

# %%
a=[]

for i in range (1,24984):
    a=a+[i]

# %%
b=[]
for i in range(100):
  b.extend(a)

# %%
b.sort()

# %%
jokes=[]

for i in range (1,101):
    jokes=jokes+[str(i)]

# %%
users=b   #length=2498300
movies=jokes*24983   #length=2498300 

ratings_dict={'userID':users,
              'itemID':movies,
              'rating':ratings}
print(ratings.size)
print(len(users))
print(len(movies))

df=pd.DataFrame(ratings_dict)
# Out:
# 2498300
# 2498300
# 2498300

# %%
df
# Out:
#          userID itemID rating
# 0             1      1  -7.82
# 1             1      2   8.79
# 2             1      3  -9.66
# 3             1      4  -8.16
# 4             1      5  -7.52
# ...         ...    ...    ...
# 2498295   24983     96    NaN
# 2498296   24983     97    NaN
# 2498297   24983     98    NaN
# 2498298   24983     99    NaN
# 2498299   24983    100    NaN
#
# [2498300 rows x 3 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#          userID itemID rating
# 0             1      1  -7.82
# 1             1      2   8.79
# 2             1      3  -9.66
# 3             1      4  -8.16
# 4             1      5  -7.52
# ...         ...    ...    ...
# 2498267   24983     68   7.48
# 2498268   24983     69   5.15
# 2498269   24983     70    3.2
# 2498270   24983     71   6.26
# 2498286   24983     87   7.23
#
# [1810455 rows x 3 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(df['rating'],bins=30)
plt.xlabel('Rating')
plt.ylabel('Number of ratings')
# Out:
# Text(0, 0.5, 'Number of ratings')

# %%
dataOf100thMovie = df[df['userID']==100]
plt.figure(figsize=(20,6))
plt.hist(dataOf100thMovie['rating'],bins=30)
plt.xlabel('Rating')
plt.ylabel('Number of ratings')
# Out:
# Text(0, 0.5, 'Number of ratings')

# %%
#remove this
newdf=df.iloc[0:1800005]

# %%
newdf
# Out:
#          userID itemID rating
# 0             1      1  -7.82
# 1             1      2   8.79
# 2             1      3  -9.66
# 3             1      4  -8.16
# 4             1      5  -7.52
# ...         ...    ...    ...
# 2483747   24838     48  -7.04
# 2483748   24838     49  -1.07
# 2483749   24838     50   9.08
# 2483750   24838     51  -3.79
# 2483751   24838     52  -0.39
#
# [1800005 rows x 3 columns]

# %%
#write df in place of newdf for final run
from surprise import Reader,Dataset
reader=Reader(rating_scale=(-10,10))
trainset=Dataset.load_from_df(df[['userID','itemID','rating']],reader).build_full_trainset()

# %%
#write df in place of newdf for final run
data=Dataset.load_from_df(df[['userID','itemID','rating']],reader)

# %%
algo=SVD()
algo.fit(trainset)

# %%
#algo_svd_res=cross_validate(algo_svd,data,measures=['rmse','mae'],cv=5,verbose=True)

# %%
algo_svd.predict(22094,'100')
# Out:
# Prediction(uid=22094, iid='100', r_ui=None, est=-7.185210339869701, details={'was_impossible': False})

# %%
algo=KNNBasic()
algo.fit(trainset)
algo_knnb_res = cross_validate(algo_knn,data,measures=['rmse','mae'],cv=5,verbose=True)
algo_knn.predict(43,'10')
# Out:
# Computing the msd similarity matrix...

# %%
algo = NMF()
algo.fit(trainset)
algo_nmf_res = cross_validate(algo_nmf,data,measures=['rmse','mae'],cv=5,verbose=True)
algo_nmf.predict(100,'7')
